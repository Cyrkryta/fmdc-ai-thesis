# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the data
val_loss_path = "/indirect/student/magnuschristensen/dev/fmdc/helper-scripts/Visualization/bs8_vl1300_300325_valloss.csv"
train_loss_path = "/indirect/student/magnuschristensen/dev/fmdc/helper-scripts/Visualization/bs8_tl450_300325_trainloss.csv"
val_loss = pd.read_csv(val_loss_path)
train_loss = pd.read_csv(train_loss_path)
val_loss_vals = val_loss["elated-water-90 - val_loss"]
train_loss_vals = train_loss["elated-water-90 - train_loss"]
epochs = train_loss["epoch"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 val_loss_path = "/indirect/student/magnuschristensen/dev/fmdc/helper-scripts/Visualization/bs8_vl1300_300325_valloss.csv"
#       3 train_loss_path = "/indirect/student/magnuschristensen/dev/fmdc/helper-scripts/Visualization/bs8_tl450_300325_trainloss.csv"
# ----> 4 val_loss = pd.read_csv(val_loss_path)
#       5 train_loss = pd.read_csv(train_loss_path)
#       6 val_loss_vals = val_loss["elated-water-90 - val_loss"]
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/indirect/student/magnuschristensen/dev/fmdc/helper-scripts/Visualization/bs8_vl1300_300325_valloss.csv'

# %%
train_loss_vals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_loss_vals
#
# NameError: name 'train_loss_vals' is not defined

# %%
plt.figure()
plt.plot(train_loss_vals, label="Training loss")
plt.plot(val_loss_vals, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Mean-Squared Error (MSE)")
plt.title("Batch Size 8, default params\n2700 train, 300 validation")
plt.legend()
plt.annotate(text=round(train_loss_vals[len(train_loss_vals)-1], 2), xy=(epochs[len(epochs)-1], train_loss_vals[len(train_loss_vals)-1]))
plt.annotate(text=round(val_loss_vals[len(val_loss_vals)-1], 2), xy=(epochs[len(epochs)-1], val_loss_vals[len(val_loss_vals)-1]))
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure()
# ----> 2 plt.plot(train_loss_vals, label="Training loss")
#       3 plt.plot(val_loss_vals, label="Validation loss")
#       4 plt.xlabel("Epoch")
#
# NameError: name 'train_loss_vals' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

bs16_all = "/users/magnuschristensen/Downloads/bs16_all.csv"
bs8_all = "/users/magnuschristensen/Downloads/bs8_all.csv"
bs8_5 = "/users/magnuschristensen/Downloads/bs8_5.csv"
bs8_single = "/users/magnuschristensen/Downloads/bs8_single.csv"

bs16_all_loss = pd.read_csv(bs16_all)
bs8_all_loss = pd.read_csv(bs8_all)
bs8_5_loss = pd.read_csv(bs8_5)
bs8_single = pd.read_csv(bs8_single)

bs16_all_loss_val = bs16_all_loss["worldly-water-88 - val_loss"]
bs8_all_loss_val = bs8_all_loss["elated-water-90 - val_loss"]
bs8_5_loss_val = bs8_5_loss["northern-haze-95 - val_loss"]
bs8_single_val = bs8_single["mild-moon-94 - val_loss"]

# %%
plt.figure(figsize=(15,5))
plt.plot(bs16_all_loss_val, label="Batch Size 16, 10 Volumes")
plt.plot(bs8_all_loss_val, label="Batch Size 8 10 Volumes")
plt.plot(bs8_5_loss_val, label="Batch Size 8, 5 Volumes")
plt.plot(bs8_single_val, label="Batch Size 8, 1 Volume")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Initial Model Comparisons")
plt.legend()
# plt.annotate(text=round(train_loss_vals[len(train_loss_vals)-1], 2), xy=(epochs[len(epochs)-1], train_loss_vals[len(train_loss_vals)-1]))
# plt.annotate(text=round(val_loss_vals[len(val_loss_vals)-1], 2), xy=(epochs[len(epochs)-1], val_loss_vals[len(val_loss_vals)-1]))
# plt.grid(True)
