m10_corr_medians = [0.9788771391489843, 0.9760852719766415, 0.9780354813057985, 0.9674999406891606, 0.9758499842885413, 0.9611123755360551, 0.9739032900561466, 0.9777354108389061, 0.962908644734508, 0.9739532769545348, 0.9811788053256029, 0.9889679403836046, 0.989929270147003, 0.988637420485778, 0.9936726501002652, 0.9869937899431835, 0.986723935744403, 0.9913037229832367, 0.9911573894997087, 0.9896536314966524, 0.9697025763525788, 0.9836396572071837, 0.9734703227623113, 0.9866027951159608, 0.9841014882466581, 0.9830362384119596, 0.979155405212444, 0.9874481494369176, 0.9890949371913527, 0.9802053285822422, 0.9936880105355348, 0.9963333192695099, 0.9966629241452251, 0.9973485926446842, 0.9981461794326989, 0.9976343631028988, 0.996633095257266, 0.9953133686389706, 0.9970896514732781, 0.996394763265662]
# Out:
# 40

# %%
all_corr_means = np.array([m1_corr_means, m2_corr_means, m3_corr_means, m4_corr_means, m5_corr_means, m6_corr_means, m7_corr_means, m8_corr_means, m9_corr_means, m10_corr_means])
all_corr_medians = np.array([m1_corr_medians, m2_corr_medians, m3_corr_medians, m4_corr_medians, m5_corr_medians, m6_corr_medians, m7_corr_medians, m8_corr_medians, m9_corr_medians, m10_corr_medians])
subject_lvl_corr_means = np.mean(all_corr_means, axis=0)
subject_lvl_corr_medians = np.median(all_corr_medians, axis=0)
overall_corr_mean = np.mean(subject_lvl_corr_means)
overall_corr_median = np.median(subject_lvl_corr_medians)
print(f"Overall correlation mean: {overall_corr_mean:.5f}")
print(f"Overall correlation median: {overall_corr_median:.5f}")    
print(subject_lvl_corr_means)
print(len(subject_lvl_corr_means))
print(subject_lvl_corr_medians)
# Out:
# Overall correlation mean: 0.90748
# Overall correlation median: 0.98731
# [0.85771821 0.84126059 0.85334884 0.83657937 0.86668607 0.83670022
#  0.85690785 0.89139861 0.84616575 0.8621557  0.87870445 0.93052951
#  0.93512673 0.93158058 0.94838645 0.93277614 0.92594061 0.93008529
#  0.94909897 0.9428524  0.84924263 0.89021234 0.86147031 0.90266385
#  0.87576457 0.86064462 0.87333035 0.9040036  0.90768157 0.87300044
#  0.95012344 0.94693841 0.96321293 0.97546064 0.98350573 0.97630813
#  0.94397229 0.96140827 0.97994323 0.96635358]
# 40
# [0.97452979 0.97646104 0.97154294 0.95653706 0.98143261 0.95654833
#  0.97606741 0.98509862 0.96010338 0.96943102 0.97948433 0.9885473
#  0.98834832 0.98876053 0.99297098 0.98693164 0.9876799  0.9903958
#  0.99131377 0.98971139 0.97311756 0.98229052 0.97519409 0.98689592
#  0.98489339 0.98457767 0.98105692 0.98772822 0.98906741 0.9822401
#  0.99293858 0.99599367 0.99669032 0.99736823 0.99793208 0.99739005
#  0.99629497 0.99575014 0.99693916 0.99664459]

# %%
print(f"Minimum: {np.min(np.mean(all_corr_means, axis=1))}")
print(f"Maximum: {np.max(np.mean(all_corr_means, axis=1))}")
# Out:
# Minimum: 0.9030950848274231
# Maximum: 0.912570303556903

# %% [markdown]
# #### MSE

# %%
m10_ssim_medians = [0.9704215159146943, 0.9652218418345974, 0.9702609517810074, 0.9670649528884093, 0.9660680724864972, 0.9657387348391073, 0.9705658848614012, 0.9699035028185992, 0.9634908975936092, 0.9656478549262084, 0.975418744974541, 0.9834065505034657, 0.9821747016390746, 0.9835631869129873, 0.9789747585704534, 0.9820078871584925, 0.9751387580120902, 0.9765215658232267, 0.9800452820446717, 0.9830061300158357, 0.9589097195348729, 0.9672954840987338, 0.9703999640891234, 0.9756070644314981, 0.9644985853995102, 0.9608774169072204, 0.9656680766141046, 0.9701498674489855, 0.9688993141667791, 0.9601735681328801, 0.9790902237601963, 0.9725097385453398, 0.9858960974942216, 0.9880643048969806, 0.9897523321386177, 0.9881403631952672, 0.9775491170431988, 0.985422475902441, 0.986970788983562, 0.9870065688139997]

# %%
all_ssim_means = np.array([m1_ssim_means, m2_ssim_means, m3_ssim_means, m4_ssim_means, m5_ssim_means, m6_ssim_means, m7_ssim_means, m8_ssim_means, m9_ssim_means, m10_ssim_means])
all_ssim_medians = np.array([m1_ssim_medians, m2_ssim_medians, m3_ssim_medians, m4_ssim_medians, m5_ssim_medians, m6_ssim_medians, m7_ssim_medians, m8_ssim_medians, m9_ssim_medians, m10_ssim_medians])
subject_lvl_ssim_means = np.mean(all_ssim_means, axis=0)
subject_lvl_ssim_medians = np.median(all_ssim_medians, axis=0)
overall_ssim_mean = np.mean(subject_lvl_ssim_means)
overall_ssim_median = np.mean(subject_lvl_ssim_medians)
print(f"Overall SSIM mean: {overall_ssim_mean:.5f}")
print(f"Overall SSIM median: {overall_ssim_median:.5f}")
print(subject_lvl_ssim_means)
print(subject_lvl_ssim_medians)
# Out:
# Overall SSIM mean: 0.97531
# Overall SSIM median: 0.97529
# [0.97076103 0.96451687 0.96975248 0.96602439 0.96908203 0.96520008
#  0.97227046 0.97368526 0.96419099 0.96551251 0.97527728 0.98366517
#  0.98248975 0.98363257 0.97876081 0.98142166 0.97559048 0.97582354
#  0.98014782 0.9827262  0.9621008  0.96959928 0.9714854  0.97811726
#  0.96761761 0.96476348 0.96719954 0.97358725 0.97194592 0.96226136
#  0.97857513 0.97304312 0.98627689 0.98823805 0.99022869 0.98835139
#  0.97785179 0.98656969 0.98671102 0.98724816]
# [0.9702559  0.96428846 0.97017377 0.96643457 0.96827044 0.96489287
#  0.97196007 0.9728204  0.96397399 0.96491707 0.97551417 0.98354239
#  0.98272222 0.98369772 0.97874744 0.98159371 0.97556798 0.97586155
#  0.98025906 0.98290079 0.96296081 0.96956224 0.97217617 0.97886173
#  0.96740402 0.96461025 0.96724754 0.97353983 0.97191809 0.96236133
#  0.97855904 0.9727035  0.98601639 0.98831053 0.98997281 0.98834711
#  0.97806015 0.98651249 0.98672122 0.98722449]

# %% [markdown]
# ##### Distorted for plotting

# %%
d_corr = [0.7972887892187266, 0.7711733480022133, 0.7838008890696745, 0.7514580388730141, 0.8436644369347768, 0.7558907790936973, 0.8279867400484606, 0.8552065668044202, 0.7707694424569176, 0.8016479795934689, 0.7414702923850368, 0.8268358075300629, 0.8269883380389541, 0.8424162462235271, 0.8324543764861219, 0.8264580305004324, 0.8159535939126963, 0.8658631464129581, 0.829957829552272, 0.8350715575412663, 0.8102110270794741, 0.8387979358941723, 0.8114422047537547, 0.7930222304702177, 0.7997262324342421, 0.7874972698959561, 0.8136567275568011, 0.8327279382617732, 0.8240206194410532, 0.8019993206299522, 0.8906891297861489, 0.8949764435777172, 0.9135393068428634, 0.9279969697086062, 0.9687702428781683, 0.9215106456537883, 0.8852262192918193, 0.9077646309978085, 0.9548037017480926, 0.9125302515676122]
d_mse = [0.005552598365987914, 0.007106935411261671, 0.005891173427182048, 0.0071191881265658475, 0.005384698389904781, 0.007173493775011165, 0.005529575051080785, 0.004868848127229284, 0.006751731175155351, 0.007629417506461304, 0.005332400039946103, 0.003694311690674165, 0.0043316816164920245, 0.003226362210711168, 0.0040393304176004775, 0.0035837584669399926, 0.005035430717000985, 0.005030407708254293, 0.0046987234037918265, 0.00379312203736814, 0.0074293605646777346, 0.006270107930426938, 0.005576953301318014, 0.006209290744660476, 0.007978300348827254, 0.0082500321744447, 0.007051959625887505, 0.006064712243829501, 0.006098091819373574, 0.007824223520124742, 0.004844990343965466, 0.004851898338296663, 0.0032155696719524617, 0.003216465139168908, 0.0015029875435297096, 0.002767106688285518, 0.004622566093968797, 0.00353353418557721, 0.0022803986704882577, 0.0031672111079180647]

# %% [markdown]
# # Plots

# %%
# Plot / Figure
fig, ax = plt.subplots(1, 2, figsize=(15,5))
positions = [1, 2]

# Violinplot for correlation
ax[0].violinplot(
    [d_corr, subject_lvl_corr_means], showmeans=True, showmedians=False,
    widths=.8, positions=[1,2]
)
ax[0].set_xticks([1, 2])
ax[0].set_xticklabels(["Distorted", "Undistorted"])
ax[0].set_xlabel("Case")
ax[0].set_ylabel("Correlation (higher is better)")
ax[0].set_title("Correlation Change")
quartile1, medians, quartile3 = np.percentile([d_corr, subject_lvl_corr_means], [25, 50, 75], axis=1)
inds = np.arange(1, len(medians) + 1)
ax[0].scatter(inds, medians, s=50, marker="o", zorder=3)
ax[0].vlines(inds, quartile1, quartile3, color="orange", linestyle="-", lw=5, alpha=0.75)

# Violinplot for mse
ax[1].violinplot(
    [d_mse, subject_lvl_mse_means], showmeans=True, showmedians=False,
    widths=.8, positions=[1,2]
)
ax[1].set_xticks([1,2])
ax[1].set_xticklabels(["Distorted", "Undistorted"])
ax[1].set_xlabel("Case")
ax[1].set_ylabel("MSE (lower is better)")
ax[1].set_title("MSE Change")
quartile1, medians, quartile3 = np.percentile([d_mse, subject_lvl_mse_means], [25, 50, 75], axis=1)
inds = np.arange(1, len(medians) + 1)
ax[1].scatter(inds, medians, s=50, zorder=3)
ax[1].vlines(inds, quartile1, quartile3, color="orange", linestyle="-", lw=5, alpha=0.75)

# %%
subjects = ["ds003835/sub-04", "ds003835/sub-05", "ds003835/sub-06", "ds003835/sub-07", "ds003835/sub-08", "ds003835/sub-09", "ds003835/sub-10", "ds003835/sub-11", "ds003835/sub-13", "ds003835/sub-14", "ds005165/sub-01", "ds005165/sub-02", "ds005165/sub-03", "ds005165/sub-04", "ds005165/sub-05", "ds005165/sub-06", "ds005165/sub-07", "ds005165/sub-08", "ds005165/sub-09", "ds005165/sub-10", "ds000224/sub-MSC01", "ds000224/sub-MSC02", "ds000224/sub-MSC03", "ds000224/sub-MSC04", "ds000224/sub-MSC05","ds000224/sub-MSC06", "ds000224/sub-MSC07", "ds000224/sub-MSC08", "ds000224/sub-MSC09", "ds000224/sub-MSC10", "ds001454/sub-01", "ds001454/sub-02", "ds001454/sub-03", "ds001454/sub-04", "ds001454/sub-05", "ds001454/sub-06", "ds001454/sub-07", "ds001454/sub-08", "ds001454/sub-09", "ds001454/sub-10"]
print(len(subjects))
# Out:
# 40

# %%
correlation_diff = np.subtract(subject_lvl_corr_means, d_corr)
fig, ax = plt.subplots(figsize=(12, 8))
bars = ax.bar(range(len(d_corr)), d_corr, color='lightgray', label='Original Correlation')
ax.bar(range(len(subject_lvl_corr_means)), subject_lvl_corr_means, color='lightblue', label='Undistorted Correlation', bottom=d_corr)
ax.bar(range(len(correlation_diff)), correlation_diff, color='orange', label='Change in Correlation', bottom=subject_lvl_corr_means)
ax.set_xticks(range(len(d_corr)))
ax.set_xticklabels(subjects, rotation=90)
ax.set_xlabel("Subjects")
ax.set_ylabel("Correlation Values")
ax.set_title("Comparison of Original, Undistorted, and Change in Correlation")
ax.legend()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(range(len(d_corr)), d_corr, color='lightgray', label='Distorted Correlation')
ax.bar(range(len(correlation_diff)), correlation_diff, color='orange', label='Change in Correlation', bottom=d_corr)
max_change_idx = np.argmax(correlation_diff)
min_change_idx = np.argmin(correlation_diff)
# ax.annotate(f'Largest change\n{subjects[max_change_idx]}', 
ax.annotate(f'Largest', 
            xy=(max_change_idx, d_corr[max_change_idx] + correlation_diff[max_change_idx] / 2),
            xytext=(max_change_idx, d_corr[max_change_idx] + correlation_diff[max_change_idx] + 0.1),
            arrowprops=dict(facecolor='black', arrowstyle="->"),
            ha='center', fontsize=10, color='black')

# ax.annotate(f'Smallest change\n{subjects[min_change_idx]}', 
ax.annotate(f'Smallest', 
            xy=(min_change_idx, d_corr[min_change_idx] + correlation_diff[min_change_idx] / 2),
            xytext=(min_change_idx, d_corr[min_change_idx] + correlation_diff[min_change_idx] - 0.1),
            arrowprops=dict(facecolor='black', arrowstyle="->"),
            ha='center', fontsize=10, color='black')
ax.set_xticks(range(len(d_corr)))
ax.set_xticklabels(subjects, rotation=45)
ax.set_xlabel("Subjects")
ax.set_ylabel("Correlation Values")
ax.set_title("Subject lvl. change in correlation")
ax.legend()
plt.tight_layout()

# %%
max_change_idx = np.argmax(correlation_diff)
min_change_idx = np.argmin(correlation_diff)
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(range(len(d_corr)), d_corr, color='lightgray', label='Distorted Correlation')
bars = ax.bar(range(len(correlation_diff)), correlation_diff, color='orange', label='Change in Correlation', bottom=d_corr)
bars[max_change_idx].set_color('green')
bars[min_change_idx].set_color('red')
ax.set_xticks(range(len(d_corr)))
ax.set_xticklabels(subjects, rotation=45, ha="right")
ax.set_xlabel("Subject")
ax.set_ylabel("Correlation")
ax.set_title("Change in correlation")
ax.legend()
plt.tight_layout()

# %% [markdown]
# #### Combined plot

# %%
philips_dist_corr_means = [0.7023524385944472, 0.7836245153787449, 0.7007340354527165, 0.7834202021809155, 0.7759158820502609, 0.7269448821943962, 0.7811251538942781, 0.5897248807708175, 0.68125740085063, 0.6689307760231191, 0.7181060814711023, 0.7512179450497032, 0.6690223208115571, 0.7168556865312545, 0.7154412995982404, 0.7047331702487368, 0.8497742923760737, 0.704168166254306, 0.7714473724415136]
philips_dist_mse_means = [0.008322501432215967, 0.006163976477325906, 0.009280486309906534, 0.005870048074029273, 0.007784039575919788, 0.009257463368018713, 0.007039780782490521, 0.014457429050445374, 0.012182989737332006, 0.011207727187923766, 0.010271445758368062, 0.00709506782993076, 0.01342442786432336, 0.011271622766803779, 0.009732801366280753, 0.009584217713529365, 0.005220295132485279, 0.012741623040043552, 0.008401895364801196]
philips_model_corr_means = [0.7574921, 0.8233204, 0.73338031, 0.79368781, 0.80687021, 0.78740086, 0.80897403, 0.64864303, 0.72104596, 0.69455842, 0.77175132, 0.79646303, 0.71321542, 0.76094384, 0.76002173, 0.75673115, 0.85816007, 0.75951503, 0.80639602]
philips_model_mse_means =  [0.00738055, 0.00517698, 0.00809678, 0.00600865, 0.00699286, 0.00714951, 0.00653841, 0.01435315, 0.01049794, 0.01101461, 0.00849762, 0.00621276, 0.01147745, 0.00958461, 0.00836362, 0.00809555, 0.00512164, 0.01113615, 0.0072406]
philips_mean_corr_means = [0.900410993887867, 0.8926553346872231, 0.8496634276639489, 0.8567807840308794, 0.8927609511633057, 0.8681977356470498, 0.8732243521134444, 0.7457404445760057, 0.7935834681476077, 0.8395909935591569, 0.8607613404864384, 0.9049912023505071, 0.8191692602301358, 0.8827148129916321, 0.8271759030948733, 0.8836939497680951, 0.8607288687836295, 0.8799269778557739, 0.9179363502829012]
philips_mean_mse_means = [0.002967305580885628, 0.003503963135402514, 0.004391007169023766, 0.00434440891730413, 0.004361039093652792, 0.0040981571503457045, 0.004915444439488127, 0.007224933582457323, 0.00887913055669888, 0.0039760621993304955, 0.004411272379002772, 0.0030614555382472114, 0.00718725777956733, 0.0053483457764417425, 0.007156949365002101, 0.004158952974945644, 0.005873467804063602, 0.0046111473161165, 0.002945263984973213]

# %%
corr_vals = [np.mean(dist_corr_means), np.mean(model_corr_means), np.mean(mean_corr_means), np.mean(synbold_corr_means), np.mean(synb0_corr_means)]
mse_vals = [np.mean(dist_mse_means), np.mean(model_mse_means), np.mean(mean_mse_means), np.mean(synbold_mse_means), np.mean(synb0_mse_means)]
labels = ["Distorted", "Model", "Mean", "SynBOLD", "SynB0 (Subset)"]
corr_stds = [np.std(dist_corr_means, ddof=1), np.std(model_corr_means, ddof=1), np.std(mean_corr_means, ddof=1), np.std(synbold_corr_means, ddof=1), 0.0]
mse_stds = [np.std(dist_mse_means, ddof=1), np.std(model_mse_means, ddof=1), np.std(mean_mse_means, ddof=1), np.std(synbold_mse_means, ddof=1), 0.0]

philips_corr_vals = [np.mean(philips_dist_corr_means), np.mean(philips_model_corr_means), np.mean(philips_mean_corr_means)]
philips_mse_vals = [np.mean(philips_dist_mse_means), np.mean(philips_model_mse_means), np.mean(philips_mean_mse_means)]
philips_labels = ["Distorted", "Model", "Mean"]
philips_corr_stds = [np.std(philips_dist_corr_means, ddof=1), np.std(philips_model_corr_means, ddof=1), np.std(philips_mean_corr_means, ddof=1)]
philips_mse_stds = [np.std(philips_dist_mse_means, ddof=1), np.std(philips_model_mse_means, ddof=1), np.std(philips_mean_mse_means, ddof=1)]

plt.figure(figsize=(15, 6))
plt.errorbar(mse_vals, corr_vals, xerr=mse_stds, yerr=corr_stds, fmt="o", ecolor="gray", elinewidth=1, capsize=2, markersize=5, label="Siemens (PED j-)")
plt.errorbar(philips_mse_vals, philips_corr_vals, xerr=philips_mse_stds, yerr=philips_corr_stds, fmt="o", color="orange", ecolor="gray", elinewidth=1, capsize=2, markersize=5, label="Philips (PED j)")             
plt.xlabel("Mean MSE (lower is better)")
plt.ylabel("Mean r (higher is better)")
plt.title("Mean MSE vs. Mean r")
plt.grid(True)

for x, y, s in zip(mse_vals + philips_mse_vals, corr_vals + philips_corr_vals, labels + philips_labels):
    s = s + ", " + str(round(y, 3))
    plt.text(x+0.0005, y+0.01, s)

plt.legend(
    loc="upper center",
    ncol=2,
    fontsize=15,
    markerscale=1.5
)

# plt.legend(
#     loc="upper center",
#     ncol=2,
#     frameon=False,
#     fontsize=16,       # increase text size
#     markerscale=1.5    # increase marker size in legend
# )
# plt.legend(loc="upper center", ncol=2, frameon=False)

# %% [markdown]
# # ds005165/sub-01 AND ds000224/sub-05

# %% [markdown]
# #### ds005165/sub-01

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

distorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/b0_d.nii.gz"
undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/b0_u.nii.gz"
undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_u_model.nii.gz"
undistorted_img = nib.load(undistorted_path)
BOLD_distorted = nib.load(distorted_path).get_fdata()
print(np.min(BOLD_distorted), np.max(BOLD_distorted))
BOLD_undistorted = nib.load(undistorted_path).get_fdata()
print(np.min(BOLD_undistorted), np.max(BOLD_undistorted))
BOLD_undistorted_model = nib.load(undistorted_model_path).get_fdata()
BOLD_diff = BOLD_undistorted - BOLD_distorted
# BOLD_diff = BOLD_undistorted_model - BOLD_distorted
print(np.min(BOLD_diff), np.max(BOLD_diff))

eps = 1e-6
# mask = (BOLD_distorted > eps)
# pct = np.zeros_like(BOLD_distorted)
# pct[mask] = (BOLD_undistorted[mask] - BOLD_distorted[mask]) / BOLD_distorted[mask] * 100
pct = (BOLD_undistorted - BOLD_distorted) / BOLD_distorted * 100

# BOLD_diff_v2 = (BOLD_undistorted - BOLD_distorted) / BOLD_undistorted * 100

print(np.min(pct), np.max(pct))
fig, ax = plt.subplots(1, 5, figsize=(20, 5))
ax[0].imshow(BOLD_distorted[:, :, BOLD_distorted.shape[2] // 2, BOLD_distorted.shape[3] // 2], cmap='gray')
ax[1].imshow(BOLD_undistorted[:, :, BOLD_undistorted.shape[2] // 2, BOLD_undistorted.shape[3] // 2], cmap='gray')
ax[2].imshow(BOLD_undistorted_model[:, :, BOLD_undistorted_model.shape[2] // 2, BOLD_undistorted_model.shape[3] // 2], cmap='gray')
ax[3].imshow(BOLD_diff[:, :, BOLD_diff.shape[2] // 2, BOLD_diff.shape[3] // 2], cmap='gray')
ax[4].imshow(pct[:, :, pct.shape[2] // 2, pct.shape[3] // 2], cmap='gray')

pct_img = nib.Nifti1Image(pct, undistorted_img.affine, undistorted_img.header)
nib.save(pct_img, '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_diff_improvement_pct_nomask.nii.gz')

# new_img = nib.Nifti1Image(BOLD_diff, undistorted_img.affine, undistorted_img.header)
# nib.save(new_img, '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_diff.nii.gz')
# Out:
# 0.0 17510.0
# 0.0 17145.44921875
# -8990.0 10837.2294921875
# /tmp/ipykernel_76413/3523126883.py:22: RuntimeWarning: divide by zero encountered in divide
#   pct = (BOLD_undistorted - BOLD_distorted) / BOLD_distorted * 100
# /tmp/ipykernel_76413/3523126883.py:22: RuntimeWarning: invalid value encountered in divide
#   pct = (BOLD_undistorted - BOLD_distorted) / BOLD_distorted * 100
# nan nan

# %%
import os
save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01"

# 1. Load raw and GT‐corrected BOLD
D_img = nib.load(distorted_path)
GT_img = nib.load(undistorted_path)

D  = D_img.get_fdata()
GT = GT_img.get_fdata()

eps  = 1e-6
mask = (D > eps)

# 2. Percent-increase map: where GT > D
pct_inc = np.zeros_like(D)
pct_inc[mask] = (GT[mask] - D[mask]) / D[mask] * 100
pct_inc = np.clip(pct_inc, 0, 100)    # only keep positive gains up to 100%

# 3. Percent-decrease map: where GT < D
pct_dec = np.zeros_like(D)
pct_dec[mask] = (D[mask] - GT[mask]) / D[mask] * 100
pct_dec = np.clip(pct_dec, 0, 100)    # only keep positive losses up to 100%

# 4. Save out
affine, hdr = D_img.affine, D_img.header
nib.save(nib.Nifti1Image(pct_inc, affine, hdr),
         os.path.join(save_root, 'gt_over_dist_pct.nii.gz'))
nib.save(nib.Nifti1Image(pct_dec, affine, hdr),
         os.path.join(save_root, 'gt_under_dist_pct.nii.gz'))

# %%
import torch
import os
from project.models.unet3d_fieldmap import UNet3DFieldmap
from project.data.data_util import normalize_img, nii2torch
import json
import tempfile
import subprocess

device = "cpu"
# def predict_fieldmap(model, bold_ref, t1_ref):
#     print(f"Input dimensions: {bold_ref.shape}, {t1_ref.shape}")
#     img_in_stack = np.stack((bold_ref, t1_ref))
#     print(f"Input image shape: {img_in_stack.shape}")
#     input_tensor = torch.from_numpy(img_in_stack).unsqueeze(0).float().to(device)
#     print(f"Input tensor of type: {type(input_tensor)}, shape: {input_tensor.shape}")
#     with torch.no_grad():
#         pred = model(input_tensor)[0].detach().cpu().numpy()
#     print(f"Pred type: {type(pred)}, dimension: {pred.shape}")
#     fieldmap_pred = pred[0]
#     print(f"Final fieldmap shape: {fieldmap_pred.shape}")
#     fieldmap_nifti = np.transpose(fieldmap_pred, axes=(1,2,0))
#     print(f"Final fieldmap shape: {fieldmap_nifti.shape}")
#     return fieldmap_nifti

def predict_fieldmap(model, input_tensor):
    print("Retrieving the fieldmap")
    with torch.no_grad():
        pred = model(input_tensor)[0].detach().cpu().numpy()
    print(f"Pred type: {type(pred)}, dimension: {pred.shape}")
    fmap_pred = pred[0]
    print(f"Final fieldmap shape: {fmap_pred.shape}")
    fmap_nifti = np.transpose(fmap_pred, axes=(1,2,0))
    print(f"Final fieldmap shape (Nifti): {fmap_nifti.shape}")
    return fmap_nifti

def apply_fugue_correction(bold_4d, pred_fieldmap, affine, echo_spacing, unwarp_direction, out_path):
    custom_tmp = "/indirect/student/magnuschristensen/dev/fmdc/fmdc-ai-thesis/helper-scripts/kfcv/tmpdir"
    print(echo_spacing, unwarp_direction)
    with tempfile.TemporaryDirectory(dir=custom_tmp) as tmpdir:
        bold_path = os.path.join(tmpdir, "bold.nii.gz")
        fmap_path = os.path.join(tmpdir, "fmap.nii.gz")
        print(bold_4d.shape, pred_fieldmap.shape)
        nib.save(nib.Nifti1Image(bold_4d, affine), bold_path)
        nib.save(nib.Nifti1Image(pred_fieldmap, affine), fmap_path)

        # Build the FUGUE command
        cmd = [
            "fugue",
            "-i", bold_path,
            "--loadfmap=" + fmap_path,
            "--dwell=" + str(echo_spacing),
            "--smooth3=3",
            "--unwarpdir=" + unwarp_direction,
            "-u", out_path
        ]

        subprocess.run(cmd, check=True)

def prepare_model_tensor(bold_path, t1w_path):
    # Load the images
    bold = nib.load(bold_path).get_fdata()
    t1w = nib.load(t1w_path).get_fdata()
    # Rep and repititions
    num_timesteps = bold.shape[3] if bold.ndim == 4 else 1
    if len(t1w.shape) == 3:
        t1w = np.repeat(t1w[None, :], num_timesteps, axis=0)
        t1w = np.transpose(t1w, axes=(1, 2, 3, 0))
    bold = nii2torch(bold)
    t1w = nii2torch(t1w)
    # Normalization
    t1w = normalize_img(t1w, 150, 0, 1, -1)
    max_bold_img = np.percentile(bold, 99)
    min_bold_img = 0
    bold = normalize_img(bold, max_bold_img, min_bold_img, 1, -1)
    bold_affine = nib.load(bold_path).affine
    # Convert to original 4d (H, W, D)
    bold_4d = np.transpose(bold, axes=(1, 2, 3, 0))
    t1w_4d = np.transpose(t1w, axes=(1, 2, 3, 0))
    # Retrieve mid index and slice
    mid_idx = bold_4d.shape[3] // 2
    bold_ref = bold_4d[:, :, :, mid_idx]
    t1w_ref = t1w_4d[:, :, :, mid_idx]
    # Construct stacked input image (Numpy, Tensor)
    input_img = np.stack((bold_ref, t1w_ref))
    print(f"Input image shape: {input_img.shape}")
    input_tensor = torch.from_numpy(input_img).unsqueeze(0).float().to(device)
    print(f"Input tensor shape: {input_tensor.shape}")
    # Return the BOLD and T1w image
    return input_tensor, bold_affine

# %%
# Load model, put to device, set to evaluation mode
model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/pt8df2wq_model0_unet3d_epoch=168_val_loss=1260.82800.ckpt"
model = UNet3DFieldmap.load_from_checkpoint(model_path, map_location=torch.device(device), encoder_map_location=torch.device(device), device=device)
model.to(device)
model.eval()
# Out:
# UNet3DFieldmap(
#   (model): UNet3D_2Module(
#     (Conv3D_1): conv3D_block(
#       (conv3D): Sequential(
#         (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (1): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): ReLU(inplace=True)
#         (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (4): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (Conv3D_2): conv3D_block(
#       (conv3D): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (1): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): ReLU(inplace=True)
#         (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
# ...

# %% [markdown]
# #### ds005165/sub-01

# %% [markdown]
# ##### Derive fieldmap and perform fugue correction

# %%
root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01"
bold_path = os.path.join(root_folder, "b0_d.nii.gz")
t1w_path = os.path.join(root_folder, "T1w.nii.gz")
input_tensor, bold_affine = prepare_model_tensor(bold_path, t1w_path)
fieldmap = predict_fieldmap(model, input_tensor)
nib.save(nib.Nifti1Image(fieldmap, bold_affine), os.path.join(root_folder, "normalized", "model_fieldmap.nii.gz"))
metadata_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/dataset_meta.json"
with open(metadata_path, "r") as f:
    data = json.load(f)
out_path = os.path.join(root_folder, "normalized", "BOLD_u_model.nii.gz")
bold_d = nib.load(bold_path).get_fdata()
apply_fugue_correction(bold_d, fieldmap, bold_affine, data["echospacing"], data["phaseencodingdirection"], out_path)
# Out:
# Input image shape: (2, 54, 76, 76)
# Input tensor shape: torch.Size([1, 2, 54, 76, 76])
# Retrieving the fieldmap
# Pred type: <class 'numpy.ndarray'>, dimension: (1, 54, 76, 76)
# Final fieldmap shape: (54, 76, 76)
# Final fieldmap shape (Nifti): (76, 76, 54)
# 0.000509996 y-
# (76, 76, 54, 212) (76, 76, 54)

# %% [markdown]
# ##### Calculate model over and undershoot

# %%
save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/normalized" 
undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/b0_u.nii.gz"
undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/normalized/BOLD_u_model.nii.gz"
gt   = nib.load(undistorted_path).get_fdata()
model= nib.load(undistorted_model_path).get_fdata()
eps  = 1e-6
mask = (gt > eps)
pct_over = np.zeros_like(gt)
pct_over[mask] = (model[mask] - gt[mask]) / gt[mask] * 100
pct_over = np.clip(pct_over, 0, 100)
nib.save(nib.Nifti1Image(pct_over,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, 'model_over_pct.nii.gz'))

pct_under = np.zeros_like(gt)
pct_under[mask] = (gt[mask] - model[mask]) / gt[mask] * 100
pct_under = np.clip(pct_under, 0, 100)
nib.save(nib.Nifti1Image(pct_under,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, "model_under_pct.nii.gz"))

# %% [markdown]
# #### ds000224/sub-MSC06

# %%
root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06"
bold_path = os.path.join(root_folder, "b0_d.nii.gz")
t1w_path = os.path.join(root_folder, "T1w.nii.gz")
input_tensor, bold_affine = prepare_model_tensor(bold_path, t1w_path)
fieldmap = predict_fieldmap(model, input_tensor)
nib.save(nib.Nifti1Image(fieldmap, bold_affine), os.path.join(root_folder, "normalized", "model_fieldmap.nii.gz"))
metadata_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/dataset_meta.json"
with open(metadata_path, "r") as f:
    data = json.load(f)
out_path = os.path.join(root_folder, "normalized", "BOLD_u_model.nii.gz")
bold_d = nib.load(bold_path).get_fdata()
apply_fugue_correction(bold_d, fieldmap, bold_affine, data["echospacing"], data["phaseencodingdirection"], out_path)
# Out:
# Input image shape: (2, 36, 64, 64)
# Input tensor shape: torch.Size([1, 2, 36, 64, 64])
# Retrieving the fieldmap
# Pred type: <class 'numpy.ndarray'>, dimension: (1, 36, 64, 64)
# Final fieldmap shape: (36, 64, 64)
# Final fieldmap shape (Nifti): (64, 64, 36)
# 0.000590001 y-
# (64, 64, 36, 818) (64, 64, 36)

# %% [markdown]
# ##### Calculate model over and undershoot

# %%
save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/normalized" 
undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/b0_u.nii.gz"
undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/normalized/BOLD_u_model.nii.gz"
gt   = nib.load(undistorted_path).get_fdata()
model= nib.load(undistorted_model_path).get_fdata()
eps  = 1e-6
mask = (gt > eps)
pct_over = np.zeros_like(gt)
pct_over[mask] = (model[mask] - gt[mask]) / gt[mask] * 100
pct_over = np.clip(pct_over, 0, 100)
nib.save(nib.Nifti1Image(pct_over,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, 'model_over_pct.nii.gz'))

pct_under = np.zeros_like(gt)
pct_under[mask] = (gt[mask] - model[mask]) / gt[mask] * 100
pct_under = np.clip(pct_under, 0, 100)
nib.save(nib.Nifti1Image(pct_under,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, "model_under_pct.nii.gz"))

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

# Load model, put to device, set to evaluation mode
model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/pt8df2wq_model0_unet3d_epoch=168_val_loss=1260.82800.ckpt"
model = UNet3DFieldmap.load_from_checkpoint(model_path, map_location=torch.device(device), encoder_map_location=torch.device(device), device=device)
model.to(device)
model.eval()

# # Load data
# # root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01"
# # root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06"
# root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds003835/sub-07"
# bold_d_path = os.path.join(root_folder, "b0_d.nii.gz")
# t1_path = os.path.join(root_folder, "T1w.nii.gz")
# bold_d = nib.load(bold_d_path).get_fdata()
# t1 = nib.load(t1_path).get_fdata()




# mid_idx = bold_d.shape[3] // 2
# print(f"Middle index: {mid_idx}")
# sliced_bold_d = bold_d[..., mid_idx]
# print(f"BOLD shape: {sliced_bold_d.shape}, T1w shape: {t1.shape}")
# t1 = np.transpose(t1, axes=(2,0,1))
# sliced_bold_d = np.transpose(sliced_bold_d, axes=(2,0,1))
# print(f"BOLD shape: {sliced_bold_d.shape}, T1w shape: {t1.shape}")
# fieldmap = predict_fieldmap(model, sliced_bold_d, t1)

# # Load metadata
# # metadata_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/dataset_meta.json"
# # metadata_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/dataset_meta.json"
# metadata_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds003835/dataset_meta.json"

# with open(metadata_path, "r") as f:
#     data = json.load(f)

# out_path = os.path.join(root_folder, "NEW", "BOLD_u_model.nii.gz")
# used_affine = nib.load(bold_d_path).affine
# apply_fugue_correction(bold_d, fieldmap, used_affine, data["echospacing"], data["phaseencodingdirection"], out_path)

# %%
nib.save(nib.Nifti1Image(fieldmap, used_affine), os.path.join(root_folder, "NEW", "model_fieldmap.nii.gz"))

# %%
gt   = nib.load(undistorted_path).get_fdata()
gt_img = nib.load(undistorted_path)
model= nib.load(undistorted_model_path).get_fdata()
print(np.min(gt), np.max(gt))
print(np.min(model), np.max(model))
diff_mg = gt - model
print(np.min(diff_mg), np.max(diff_mg))
pct = (model - BOLD_distorted) / BOLD_distorted * 100
pct_img = nib.Nifti1Image(pct, gt_img.affine, gt_img.header)
nib.save(pct_img, '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/distmode_improvement_pct_nomask.nii.gz')

# %% [markdown]
# # Model overshoot

# %%
# save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/NEW" 
# save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/NEW" 
save_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds003835/sub-07/NEW" 

# undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/b0_u.nii.gz"
# undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/b0_u.nii.gz"
undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds003835/sub-07/b0_u.nii.gz"


# undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/NEW/BOLD_u_model.nii.gz"
# undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06/NEW/BOLD_u_model.nii.gz"
undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds003835/sub-07/NEW/BOLD_u_model.nii.gz"

gt   = nib.load(undistorted_path).get_fdata()
model= nib.load(undistorted_model_path).get_fdata()
eps  = 1e-6
mask = (gt > eps)

pct_over = np.zeros_like(gt)
pct_over[mask] = (model[mask] - gt[mask]) / gt[mask] * 100
pct_over = np.clip(pct_over, 0, 100)
nib.save(nib.Nifti1Image(pct_over,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, 'model_over_pct.nii.gz'))

pct_under = np.zeros_like(gt)
pct_under[mask] = (gt[mask] - model[mask]) / gt[mask] * 100
pct_under = np.clip(pct_under, 0, 100)
nib.save(nib.Nifti1Image(pct_under,
                         nib.load(undistorted_path).affine,
                         nib.load(undistorted_path).header),
                         os.path.join(save_root, "model_under_pct.nii.gz"))

# %%
gt   = nib.load(undistorted_path).get_fdata()
gt_img = nib.load(undistorted_path)
model= nib.load(undistorted_model_path).get_fdata()
eps  = 1e-6
mask = (gt > eps)
pct_gtm = np.zeros_like(gt)
pct_gtm[mask] = (model[mask] - gt[mask]) / gt[mask] * 100
pct_gtm = np.clip(pct_gtm, 0, 100)
nib.save(
  nib.Nifti1Image(pct_gtm, 
                  nib.load(undistorted_path).affine, 
                  nib.load(undistorted_path).header),
  '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/model_vs_gt_pct.nii.gz'
)

# %%
gt   = nib.load(undistorted_path).get_fdata()
model= nib.load(undistorted_model_path).get_fdata()
resid = gt - model
eps = 1e-6
mask = (model > eps)
pct_err[mask] = (gt[maks])

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

distorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/b0_d.nii.gz"
undistorted_model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_u_model.nii.gz"
undistorted_img = nib.load(undistorted_path)
BOLD_distorted = nib.load(distorted_path).get_fdata()
print(np.min(BOLD_distorted), np.max(BOLD_distorted))
BOLD_undistorted = nib.load(undistorted_path).get_fdata()
print(np.min(BOLD_undistorted), np.max(BOLD_undistorted))
BOLD_undistorted_model = nib.load(undistorted_model_path).get_fdata()
# BOLD_diff = BOLD_undistorted - BOLD_distorted
BOLD_diff = BOLD_undistorted_model - BOLD_distorted
print(np.min(BOLD_diff), np.max(BOLD_diff))

eps = 1e-6
# mask = (BOLD_undistorted > eps)
mask = (BOLD_distorted > eps)
# pct = np.zeros_like(BOLD_undistorted)
pct = np.zeros_like(BOLD_distorted)
# pct[mask] = (BOLD_undistorted[mask] - BOLD_distorted[mask]) / BOLD_undistorted[mask] * 100
pct[mask] = (BOLD_undistorted[mask] - BOLD_distorted[mask]) / BOLD_distorted[mask] * 100

# BOLD_diff_v2 = (BOLD_undistorted - BOLD_distorted) / BOLD_undistorted * 100

print(np.min(pct), np.max(pct))
fig, ax = plt.subplots(1, 5, figsize=(20, 5))
ax[0].imshow(BOLD_distorted[:, :, BOLD_distorted.shape[2] // 2, BOLD_distorted.shape[3] // 2], cmap='gray')
ax[1].imshow(BOLD_undistorted[:, :, BOLD_undistorted.shape[2] // 2, BOLD_undistorted.shape[3] // 2], cmap='gray')
ax[2].imshow(BOLD_undistorted_model[:, :, BOLD_undistorted_model.shape[2] // 2, BOLD_undistorted_model.shape[3] // 2], cmap='gray')
ax[3].imshow(BOLD_diff[:, :, BOLD_diff.shape[2] // 2, BOLD_diff.shape[3] // 2], cmap='gray')
ax[4].imshow(pct[:, :, pct.shape[2] // 2, pct.shape[3] // 2], cmap='gray')

pct_img = nib.Nifti1Image(pct, undistorted_img.affine, undistorted_img.header)
nib.save(pct_img, '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_diff_improvement_pct.nii.gz')

# new_img = nib.Nifti1Image(BOLD_diff, undistorted_img.affine, undistorted_img.header)
# nib.save(new_img, '/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds005165/sub-01/BOLD_diff.nii.gz')

# %%
plt.figure(1)
plt.imshow(fieldmap[:, :, fieldmap.shape[2] // 2], cmap='gray')

# %%
from project.models.unet3d_fieldmap import UNet3DFieldmap
model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/bnn21ltx_model7_unet3d_epoch=191_val_loss=1307.36890.ckpt"
model = UNet3DFieldmap.load_from_checkpoint(model_path, map_location=torch.device(device), encoder_map_location=torch.device(device), device=device)
model.to(device)
model.eval()
# device = "cpu"
# model = torch.load(model_path, map_location=torch.device(device))
# model.to(device)

# %% [markdown]
# #### ds000224/sub-06

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
subject_root = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed/ds000224/sub-MSC06"
undistorted_path_sub6 = os.path.join(subject_root, "b0_u.nii.gz")
undistorted_model_path_sub6 = os.path.join(subject_root, "BOLD_u_model.nii.gz")

gt   = nib.load(undistorted_path_sub6).get_fdata()
model= nib.load(undistorted_model_path_sub6).get_fdata()
eps  = 1e-6
mask = (gt > eps)

pct_over = np.zeros_like(gt)
pct_over[mask] = (model[mask] - gt[mask]) / gt[mask] * 100
pct_over = np.clip(pct_over, 0, 100)
nib.save(nib.Nifti1Image(pct_over,
                         nib.load(undistorted_path_sub6).affine,
                         nib.load(undistorted_path_sub6).header),
                         os.path.join(subject_root, 'model_over_pct.nii.gz'))

pct_under = np.zeros_like(gt)
pct_under[mask] = (gt[mask] - model[mask]) / gt[mask] * 100
pct_under = np.clip(pct_under, 0, 100)
nib.save(nib.Nifti1Image(pct_under,
                         nib.load(undistorted_path_sub6).affine,
                         nib.load(undistorted_path_sub6).header),
                         os.path.join(subject_root, "model_under_pct.nii.gz"))


# distorted_path_sub6 = os.path.join(subject_root, "b0_d.nii.gz")

# # 1. Load raw and GT‐corrected BOLD
# D_img = nib.load(distorted_path_sub6)
# GT_img = nib.load(undistorted_path_sub6)

# D  = D_img.get_fdata()
# GT = GT_img.get_fdata()

# eps  = 1e-6
# mask = (D > eps)

# # 2. Percent-increase map: where GT > D
# pct_inc = np.zeros_like(D)
# pct_inc[mask] = (GT[mask] - D[mask]) / D[mask] * 100
# pct_inc = np.clip(pct_inc, 0, 100)    # only keep positive gains up to 100%

# # 3. Percent-decrease map: where GT < D
# pct_dec = np.zeros_like(D)
# pct_dec[mask] = (D[mask] - GT[mask]) / D[mask] * 100
# pct_dec = np.clip(pct_dec, 0, 100)    # only keep positive losses up to 100%

# # 4. Save out
# affine, hdr = D_img.affine, D_img.header
# nib.save(nib.Nifti1Image(pct_inc, affine, hdr),
#          os.path.join(subject_root, 'gt_over_dist_pct.nii.gz'))
# nib.save(nib.Nifti1Image(pct_dec, affine, hdr),
#          os.path.join(subject_root, 'gt_under_dist_pct.nii.gz'))

# %%
# Compute voxel-wise changes
correlation_diff = np.subtract(subject_lvl_corr_means, d_corr)
mse_diff = np.subtract(subject_lvl_mse_means, d_mse)

# Create a new figure with two rows
fig, ax = plt.subplots(2, 1, figsize=(12, 8))  # Adjust figure size for better readability

# **Subplot 1: Correlation Differences**
ax[0].bar(range(len(correlation_diff)), correlation_diff, 
          color=["orange" if x < 0 else "lightblue" for x in correlation_diff])
ax[0].set_xticks(range(len(correlation_diff)))
# ax[0].set_xticklabels(subjects, rotation=90)
ax[0].set_ylabel("Change in Correlation")
ax[1].set_xticklabels(subjects, rotation=90)
ax[1].set_ylabel("Change in MSE")
ax[1].set_title("Voxel-wise Changes in MSE")

# Improve layout
plt.tight_layout()
