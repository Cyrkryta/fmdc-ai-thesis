m5_mse_medians = [0.0020122870378189977, 0.001421885694034669, 0.001693835131481684, 0.001302951076568328, 0.0014959005401138253, 0.000951546568927196, 0.0012851883625034973, 0.0017496482348969863, 0.001332457686191905, 0.002823064877625925]
m6_mse_medians = [0.0021779098385838495, 0.0015557196700845405, 0.0017790064859443844, 0.0013472170593385564, 0.0016742732055349046, 0.0010647932772578257, 0.0014022103284054722, 0.0016420277622188413, 0.0013634618553343683, 0.003254244258499594]
m7_mse_medians = [0.002063114034603371, 0.0015201714970894918, 0.0017562820915316157, 0.0013105206347846319, 0.0015900466828743854, 0.0010006232397841925, 0.001308705236545851, 0.0016301404521379338, 0.0013445559919063074, 0.0029707857734255164]
m8_mse_medians = [0.0020070256077159795, 0.0014830186966029515, 0.001776419321693129, 0.0013386206062213006, 0.0016165843993654564, 0.0009884320312136866, 0.0011771477716608842, 0.001685345159467204, 0.0012679252655565347, 0.0029910240400093345]
m9_mse_medians = [0.0020682876897884445, 0.0015069762495175307, 0.001772453673243623, 0.001353562849751327, 0.0015591050701236372, 0.0010550622482673848, 0.0014548527353680754, 0.0017519731419316084, 0.0014868694834182117, 0.0029065301862297712]
m10_mse_medians = [0.0021757076492397854, 0.001651182569974118, 0.001758648400960064, 0.0014487174972660478, 0.001548565194400097, 0.0011286411275167147, 0.0014291413599483126, 0.001680982291012717, 0.0014171292082259014, 0.0032050802962284497]

# %%
all_mse_means = np.array([m1_mse_means, m2_mse_means, m3_mse_means, m4_mse_means, m5_mse_means, m6_mse_means, m7_mse_means, m8_mse_means, m9_mse_means, m10_mse_means])
all_mse_medians = np.array([m1_mse_medians, m2_mse_medians, m3_mse_medians, m4_mse_medians, m5_mse_medians, m6_mse_medians, m7_mse_medians, m8_mse_medians, m9_mse_medians, m10_mse_medians])
subject_lvl_mse_means = np.mean(all_mse_means, axis=0)
subject_lvl_mse_medians = np.median(all_mse_medians, axis=0)
overall_mse_mean = np.mean(subject_lvl_mse_means)
overall_mse_median = np.median(subject_lvl_mse_medians)
print(f"Overall MSE mean: {overall_mse_mean:.5f}")
print(f"Overall MSE median: {overall_mse_median:.5f}")
print(subject_lvl_mse_means)
print(subject_lvl_mse_medians)
# Out:
# Overall MSE mean: 0.00167
# Overall MSE median: 0.00154
# [0.00201766 0.00148112 0.00179734 0.00136801 0.00158364 0.00106029
#  0.00133313 0.00169209 0.00135712 0.003037  ]
# [0.00205793 0.00151357 0.00175747 0.00135039 0.00157458 0.00105632
#  0.0013402  0.00168316 0.00136891 0.0029809 ]

# %% [markdown]
# ##### SSIM

# %%
m1_ssim_means = [0.9809057505519493, 0.9889062704903898, 0.9834314270066032, 0.9872184960609449, 0.9844523447897757, 0.9880811491422352, 0.9861538380611061, 0.9838723996415196, 0.9873040314923808, 0.9768909647639976]
m2_ssim_means = [0.9800270363560413, 0.9884890111396889, 0.984201783182566, 0.9869187075666103, 0.98542698920992, 0.987596886080199, 0.985031125902199, 0.9844778733584602, 0.986896419672515, 0.9768963661294353]
m7_ssim_medians = [0.9800691032847162, 0.9890977779934942, 0.9840589917306545, 0.9880690847841112, 0.9848332561741806, 0.9887374056557465, 0.9863609622770901, 0.9842364192600028, 0.987699420278033, 0.9779125994849984]
m8_ssim_medians = [0.9805248142458463, 0.9894608278494489, 0.9837054005496519, 0.9877785852904098, 0.9844691133840293, 0.9890148813671794, 0.9874462323459625, 0.9839424455925996, 0.9883821790539017, 0.977642120805505]
m9_ssim_medians = [0.9800906076330014, 0.9889468145123839, 0.9836014031818114, 0.9874188224764544, 0.9847933687958194, 0.9877066512799795, 0.9845852895562568, 0.9834130541417658, 0.986359721823358, 0.9779012025793705]
m10_ssim_medians = [0.9792060093153538, 0.9882770232052471, 0.9839751348788024, 0.9865841192130648, 0.9850972013182729, 0.987257991981365, 0.9852005370111143, 0.9838978932654712, 0.9870011568274526, 0.9763659624362899]

# %%
all_ssim_means = np.array([m1_ssim_means, m2_ssim_means, m3_ssim_means, m4_ssim_means, m5_ssim_means, m6_ssim_means, m7_ssim_means, m8_ssim_means, m9_ssim_means, m10_ssim_means])
all_ssim_medians = np.array([m1_ssim_medians, m2_ssim_medians, m3_ssim_medians, m4_ssim_medians, m5_ssim_medians, m6_ssim_medians, m7_ssim_medians, m8_ssim_medians, m9_ssim_medians, m10_ssim_medians])
subject_lvl_ssim_means = np.mean(all_ssim_means, axis=0)
subject_lvl_ssim_medians = np.median(all_ssim_medians, axis=0)
overall_ssim_mean = np.mean(subject_lvl_ssim_means)
overall_ssim_median = np.mean(subject_lvl_ssim_medians)
print(f"Overall SSIM mean: {overall_ssim_mean:.5f}")
print(f"Overall SSIM median: {overall_ssim_median:.5f}")
print(subject_lvl_ssim_means)
print(subject_lvl_ssim_medians)
# Out:
# Overall SSIM mean: 0.98487
# Overall SSIM median: 0.98482
# [0.98074306 0.98908677 0.98404068 0.98735882 0.98497639 0.98824368
#  0.98585482 0.98380634 0.98737573 0.97726367]
# [0.98009108 0.98907256 0.98401706 0.98743971 0.98481331 0.98795781
#  0.98588214 0.98390071 0.98744345 0.97758634]

# %% [markdown]
# # Fieldmap example

# %%
import nibabel as nib
import matplotlib.pyplot as plt

BOLD_distorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04/b0_d.nii.gz"
BOLD_undistorted_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04/b0_u.nii.gz"
t1w_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04/T1w.nii.gz"
fieldmap_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04/field_map.nii.gz"

BOLD_distorted = nib.load(BOLD_distorted_path)
BOLD_undistorted = nib.load(BOLD_undistorted_path)
t1w = nib.load(t1w_path)
fieldmap = nib.load(fieldmap_path)

BOLD_distorted_data = BOLD_distorted.get_fdata()
BOLD_undistorted_data = BOLD_undistorted.get_fdata()
t1w_data = t1w.get_fdata()
fieldmap_data = fieldmap.get_fdata()
print(BOLD_distorted_data.shape, BOLD_undistorted_data.shape, t1w_data.shape, fieldmap_data.shape)

fig, axs = plt.subplots(1, 5, figsize=(15, 5))
axs[0].imshow(BOLD_distorted_data[:, :, BOLD_distorted_data.shape[2] // 2, BOLD_distorted_data.shape[3] // 3], cmap="gray")
axs[0].set_title("BOLD Distorted")
axs[1].imshow(BOLD_undistorted_data[:, :, BOLD_undistorted_data.shape[2] // 2, BOLD_undistorted_data.shape[3] // 3], cmap="gray")
axs[1].set_title("BOLD Undistorted")
axs[2].imshow(t1w_data[:, :, t1w_data.shape[2] // 2], cmap="gray")
axs[2].set_title("T1w Image")
axs[3].imshow(fieldmap_data[:, :, fieldmap_data.shape[2] // 2, 0], cmap="gray")
axs[3].set_title("GT fieldmap")
diff = BOLD_undistorted_data - BOLD_distorted_data
axs[4].imshow(diff[:, :, diff.shape[2] // 2, diff.shape[3] // 2], cmap="gray")
# Out:
# (64, 64, 44, 242) (64, 64, 44, 242) (64, 64, 44) (64, 64, 44, 2)

# %%
import torch
import os
from project.models.unet3d_fieldmap import UNet3DFieldmap
from project.data.data_util import normalize_img, nii2torch
import json
import tempfile
import subprocess
import nibabel as nib

device = "cpu"

def predict_fieldmap(model, input_tensor):
    print("Retrieving the fieldmap")
    with torch.no_grad():
        pred = model(input_tensor)[0].detach().cpu().numpy()
    print(f"Pred type: {type(pred)}, dimension: {pred.shape}")
    fmap_pred = pred[0]
    print(f"Final fieldmap shape: {fmap_pred.shape}")
    fmap_nifti = np.transpose(fmap_pred, axes=(1,2,0))
    print(f"Final fieldmap shape (Nifti): {fmap_nifti.shape}")
    return fmap_nifti

def apply_fugue_correction(bold_4d, pred_fieldmap, affine, echo_spacing, unwarp_direction, out_path):
    custom_tmp = "/indirect/student/magnuschristensen/dev/fmdc/fmdc-ai-thesis/helper-scripts/kfcv/tmpdir"
    print(echo_spacing, unwarp_direction)
    with tempfile.TemporaryDirectory(dir=custom_tmp) as tmpdir:
        bold_path = os.path.join(tmpdir, "bold.nii.gz")
        fmap_path = os.path.join(tmpdir, "fmap.nii.gz")
        print(bold_4d.shape, pred_fieldmap.shape)
        nib.save(nib.Nifti1Image(bold_4d, affine), bold_path)
        nib.save(nib.Nifti1Image(pred_fieldmap, affine), fmap_path)

        # Build the FUGUE command
        cmd = [
            "fugue",
            "-i", bold_path,
            "--loadfmap=" + fmap_path,
            "--dwell=" + str(echo_spacing),
            "--smooth3=3",
            "--unwarpdir=" + unwarp_direction,
            "-u", out_path
        ]

        subprocess.run(cmd, check=True)

def prepare_model_tensor(bold_path, t1w_path):
    # Load the images
    bold = nib.load(bold_path).get_fdata()
    t1w = nib.load(t1w_path).get_fdata()
    # Rep and repititions
    num_timesteps = bold.shape[3] if bold.ndim == 4 else 1
    if len(t1w.shape) == 3:
        t1w = np.repeat(t1w[None, :], num_timesteps, axis=0)
        t1w = np.transpose(t1w, axes=(1, 2, 3, 0))
    bold = nii2torch(bold)
    t1w = nii2torch(t1w)
    # Normalization
    t1w = normalize_img(t1w, 150, 0, 1, -1)
    max_bold_img = np.percentile(bold, 99)
    min_bold_img = 0
    bold = normalize_img(bold, max_bold_img, min_bold_img, 1, -1)
    bold_affine = nib.load(bold_path).affine
    # Convert to original 4d (H, W, D)
    bold_4d = np.transpose(bold, axes=(1, 2, 3, 0))
    t1w_4d = np.transpose(t1w, axes=(1, 2, 3, 0))
    # Retrieve mid index and slice
    mid_idx = bold_4d.shape[3] // 2
    bold_ref = bold_4d[:, :, :, mid_idx]
    t1w_ref = t1w_4d[:, :, :, mid_idx]
    # Construct stacked input image (Numpy, Tensor)
    input_img = np.stack((bold_ref, t1w_ref))
    print(f"Input image shape: {input_img.shape}")
    input_tensor = torch.from_numpy(input_img).unsqueeze(0).float().to(device)
    print(f"Input tensor shape: {input_tensor.shape}")
    # Return the BOLD and T1w image
    return input_tensor, bold_affine

# %%
# Load model, put to device, set to evaluation mode
model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/pt8df2wq_model0_unet3d_epoch=168_val_loss=1260.82800.ckpt"
model = UNet3DFieldmap.load_from_checkpoint(model_path, map_location=torch.device(device), encoder_map_location=torch.device(device), device=device)
model.to(device)
model.eval()
# Out:
# UNet3DFieldmap(
#   (model): UNet3D_2Module(
#     (Conv3D_1): conv3D_block(
#       (conv3D): Sequential(
#         (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (1): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): ReLU(inplace=True)
#         (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (4): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (Conv3D_2): conv3D_block(
#       (conv3D): Sequential(
#         (0): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         (1): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): ReLU(inplace=True)
#         (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
# ...

# %%
root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04"
bold_path = os.path.join(root_folder, "b0_d.nii.gz")
t1w_path = os.path.join(root_folder, "T1w.nii.gz")
input_tensor, bold_affine = prepare_model_tensor(bold_path, t1w_path)
fieldmap = predict_fieldmap(model, input_tensor)
nib.save(nib.Nifti1Image(fieldmap, bold_affine), os.path.join(root_folder, "normalized", "model_fieldmap.nii.gz"))
# Out:
# Input image shape: (2, 44, 64, 64)
# Input tensor shape: torch.Size([1, 2, 44, 64, 64])
# Retrieving the fieldmap
# Pred type: <class 'numpy.ndarray'>, dimension: (1, 44, 64, 64)
# Final fieldmap shape: (44, 64, 64)
# Final fieldmap shape (Nifti): (64, 64, 44)

# %%
# model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/bnn21ltx_model7_unet3d_epoch=191_val_loss=1307.36890.ckpt"
# ckpt = torch.load(model_path, map_location=device)
# sd   = ckpt.get("state_dict", ckpt)
# model = UNet3DFieldmap()
# model.load_state_dict(sd, strict=True)
# model.to(device)
# model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/bnn21ltx_model7_unet3d_epoch=191_val_loss=1307.36890.ckpt"
model_path = "/indirect/student/magnuschristensen/dev/fmdc/downloads/kfcv-ckpt-AP/pt8df2wq_model0_unet3d_epoch=168_val_loss=1260.82800.ckpt"
model = UNet3DFieldmap.load_from_checkpoint(model_path, map_location=torch.device(device), encoder_map_location=torch.device(device), device=device)
model.to(device)
model.eval()

root_folder = "/indirect/student/magnuschristensen/dev/fmdc/downloads/processed-datasets/test-processed-x/ds002898/sub-04"
bold_d_path = os.path.join(root_folder, "b0_d.nii.gz")
t1_path = os.path.join(root_folder, "T1w.nii.gz")
bold_d = nib.load(bold_d_path).get_fdata()
t1 = nib.load(t1_path).get_fdata()
mid_idx = bold_d.shape[3] // 2
print(f"Middle index: {mid_idx}")
sliced_bold_d = bold_d[..., mid_idx]
print(f"BOLD shape: {sliced_bold_d.shape}, T1w shape: {t1.shape}")
t1 = np.transpose(t1, axes=(2,0,1))
sliced_bold_d = np.transpose(sliced_bold_d, axes=(2,0,1))
print(f"BOLD shape: {sliced_bold_d.shape}, T1w shape: {t1.shape}")
fieldmap = predict_fieldmap(model, sliced_bold_d, t1)
used_affine = nib.load(bold_d_path).affine
nib.save(nib.Nifti1Image(fieldmap, used_affine), os.path.join(root_folder, "NEW", "model_fieldmap.nii.gz"))
# Out:
# Middle index: 121
# BOLD shape: (64, 64, 44), T1w shape: (64, 64, 44)
# BOLD shape: (44, 64, 64), T1w shape: (44, 64, 64)
# Input dimensions: (44, 64, 64), (44, 64, 64)
# Input image shape: (2, 44, 64, 64)
# Input tensor of type: <class 'torch.Tensor'>, shape: torch.Size([1, 2, 44, 64, 64])
# Pred type: <class 'numpy.ndarray'>, dimension: (1, 44, 64, 64)
# Final fieldmap shape: (44, 64, 64)
# Final fieldmap shape: (64, 64, 44)
